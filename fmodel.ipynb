# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from tensorflow import keras

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers import Dropout, Lambda
from keras.layers import Conv2D, Conv2DTranspose
from keras.layers import MaxPooling2D
from keras.layers import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3
TRAIN_PATH = 'C:\\Users\\humza\\U-NetBioMedSegmentation\\stage1_train'
TEST_PATH = 'C:\\Users\\humza\\U-NetBioMedSegmentation\\stage1_test'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
random.seed = 42
np.random.seed = 42

# %%
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %%
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + '\\' + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant', 
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)
    Y_train[n] = mask

X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + '\\' + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 670/670 [09:06<00:00,  1.23it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:02<00:00, 31.32it/s]
# Done!

# %%
ix = random.randint(0, len(train_ids))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()

# %%
def mean_iou(y_true, y_pred):

    def f(y_true, y_pred):
        intersection = (y_true * y_pred).sum()
        union = y_true.sum() + y_pred.sum() - intersection
        x = (intersection + 1e-15) / (union + 1e-15)
        x = x.astype(np.float32)
        return x
    return tf.numpy_function(f, [y_true, y_pred], tf.float32)

# %%
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (s)
c1 = Dropout(0.1) (c1)
c1 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p1)
c2 = Dropout(0.1) (c2)
c2 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p2)
c3 = Dropout(0.2) (c3)
c3 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p3)
c4 = Dropout(0.2) (c4)
c4 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (p4)
c5 = Dropout(0.3) (c5)
c5 = Conv2D(256, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c5)

u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u6)
c6 = Dropout(0.2) (c6)
c6 = Conv2D(128, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c6)

u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u7)
c7 = Dropout(0.2) (c7)
c7 = Conv2D(64, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c7)

u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u8)
c8 = Dropout(0.1) (c8)
c8 = Conv2D(32, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c8)

u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (u9)
c9 = Dropout(0.1) (c9)
c9 = Conv2D(16, (3, 3), activation='elu', kernel_initializer='he_normal', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[mean_iou])
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_6 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  lambda_5 (Lambda)           (None, 128, 128, 3)          0         ['input_6[0][0]']
#
#  conv2d_95 (Conv2D)          (None, 128, 128, 16)         448       ['lambda_5[0][0]']
#
#  dropout_45 (Dropout)        (None, 128, 128, 16)         0         ['conv2d_95[0][0]']
#
#  conv2d_96 (Conv2D)          (None, 128, 128, 16)         2320      ['dropout_45[0][0]']
#
#  max_pooling2d_20 (MaxPooli  (None, 64, 64, 16)           0         ['conv2d_96[0][0]']
#  ng2D)
#
#  conv2d_97 (Conv2D)          (None, 64, 64, 32)           4640      ['max_pooling2d_20[0][0]']
#
#  dropout_46 (Dropout)        (None, 64, 64, 32)           0         ['conv2d_97[0][0]']
#
#  conv2d_98 (Conv2D)          (None, 64, 64, 32)           9248      ['dropout_46[0][0]']
#
#  max_pooling2d_21 (MaxPooli  (None, 32, 32, 32)           0         ['conv2d_98[0][0]']
#  ng2D)
#
#  conv2d_99 (Conv2D)          (None, 32, 32, 64)           18496     ['max_pooling2d_21[0][0]']
#
#  dropout_47 (Dropout)        (None, 32, 32, 64)           0         ['conv2d_99[0][0]']
#
#  conv2d_100 (Conv2D)         (None, 32, 32, 64)           36928     ['dropout_47[0][0]']
#
#  max_pooling2d_22 (MaxPooli  (None, 16, 16, 64)           0         ['conv2d_100[0][0]']
#  ng2D)
#
#  conv2d_101 (Conv2D)         (None, 16, 16, 128)          73856     ['max_pooling2d_22[0][0]']
#
#  dropout_48 (Dropout)        (None, 16, 16, 128)          0         ['conv2d_101[0][0]']
#
#  conv2d_102 (Conv2D)         (None, 16, 16, 128)          147584    ['dropout_48[0][0]']
#
#  max_pooling2d_23 (MaxPooli  (None, 8, 8, 128)            0         ['conv2d_102[0][0]']
#  ng2D)
#
#  conv2d_103 (Conv2D)         (None, 8, 8, 256)            295168    ['max_pooling2d_23[0][0]']
#
#  dropout_49 (Dropout)        (None, 8, 8, 256)            0         ['conv2d_103[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 8, 8, 256)            590080    ['dropout_49[0][0]']
#
#  conv2d_transpose_20 (Conv2  (None, 16, 16, 128)          131200    ['conv2d_104[0][0]']
#  DTranspose)
#
#  concatenate_20 (Concatenat  (None, 16, 16, 256)          0         ['conv2d_transpose_20[0][0]',
#  e)                                                                  'conv2d_102[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 16, 16, 128)          295040    ['concatenate_20[0][0]']
#
#  dropout_50 (Dropout)        (None, 16, 16, 128)          0         ['conv2d_105[0][0]']
#
#  conv2d_106 (Conv2D)         (None, 16, 16, 128)          147584    ['dropout_50[0][0]']
#
#  conv2d_transpose_21 (Conv2  (None, 32, 32, 64)           32832     ['conv2d_106[0][0]']
#  DTranspose)
#
#  concatenate_21 (Concatenat  (None, 32, 32, 128)          0         ['conv2d_transpose_21[0][0]',
#  e)                                                                  'conv2d_100[0][0]']
#
#  conv2d_107 (Conv2D)         (None, 32, 32, 64)           73792     ['concatenate_21[0][0]']
#
#  dropout_51 (Dropout)        (None, 32, 32, 64)           0         ['conv2d_107[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 32, 32, 64)           36928     ['dropout_51[0][0]']
#
#  conv2d_transpose_22 (Conv2  (None, 64, 64, 32)           8224      ['conv2d_108[0][0]']
#  DTranspose)
#
#  concatenate_22 (Concatenat  (None, 64, 64, 64)           0         ['conv2d_transpose_22[0][0]',
#  e)                                                                  'conv2d_98[0][0]']
#
#  conv2d_109 (Conv2D)         (None, 64, 64, 32)           18464     ['concatenate_22[0][0]']
#
#  dropout_52 (Dropout)        (None, 64, 64, 32)           0         ['conv2d_109[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 64, 64, 32)           9248      ['dropout_52[0][0]']
#
#  conv2d_transpose_23 (Conv2  (None, 128, 128, 16)         2064      ['conv2d_110[0][0]']
#  DTranspose)
#
#  concatenate_23 (Concatenat  (None, 128, 128, 32)         0         ['conv2d_transpose_23[0][0]',
#  e)                                                                  'conv2d_96[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 128, 128, 16)         4624      ['concatenate_23[0][0]']
#
#  dropout_53 (Dropout)        (None, 128, 128, 16)         0         ['conv2d_111[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 128, 128, 16)         2320      ['dropout_53[0][0]']
#
#  conv2d_113 (Conv2D)         (None, 128, 128, 1)          17        ['conv2d_112[0][0]']
#
# ==================================================================================================
# Total params: 1941105 (7.40 MB)
# Trainable params: 1941105 (7.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=16, epochs=10, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Epoch 1/10
# 38/38 [==============================] - ETA: 0s - loss: 0.1029 - mean_iou: 0.7899
# Epoch 1: val_loss improved from inf to 0.09591, saving model to model-dsbowl2018-1.h5
# 38/38 [==============================] - 56s 1s/step - loss: 0.1029 - mean_iou: 0.7899 - val_loss: 0.0959 - val_mean_iou: 0.8070
# Epoch 2/10
# 38/38 [==============================] - ETA: 0s - loss: 0.1028 - mean_iou: 0.7879
# Epoch 2: val_loss improved from 0.09591 to 0.08606, saving model to model-dsbowl2018-1.h5
# 38/38 [==============================] - 57s 1s/step - loss: 0.1028 - mean_iou: 0.7879 - val_loss: 0.0861 - val_mean_iou: 0.8232
# Epoch 3/10
# 38/38 [==============================] - ETA: 0s - loss: 0.1029 - mean_iou: 0.7887
# Epoch 3: val_loss did not improve from 0.08606
# 38/38 [==============================] - 51s 1s/step - loss: 0.1029 - mean_iou: 0.7887 - val_loss: 0.0915 - val_mean_iou: 0.8165
# Epoch 4/10
# 38/38 [==============================] - ETA: 0s - loss: 0.0984 - mean_iou: 0.7988
# Epoch 4: val_loss improved from 0.08606 to 0.08479, saving model to model-dsbowl2018-1.h5
# 38/38 [==============================] - 52s 1s/step - loss: 0.0984 - mean_iou: 0.7988 - val_loss: 0.0848 - val_mean_iou: 0.8281
# Epoch 5/10
# 38/38 [==============================] - ETA: 0s - loss: 0.0972 - mean_iou: 0.7995
# Epoch 5: val_loss improved from 0.08479 to 0.08458, saving model to model-dsbowl2018-1.h5
# 38/38 [==============================] - 47s 1s/step - loss: 0.0972 - mean_iou: 0.7995 - val_loss: 0.0846 - val_mean_iou: 0.8357
# Epoch 6/10
# 38/38 [==============================] - ETA: 0s - loss: 0.0945 - mean_iou: 0.8035
# Epoch 6: val_loss did not improve from 0.08458
# 38/38 [==============================] - 47s 1s/step - loss: 0.0945 - mean_iou: 0.8035 - val_loss: 0.0873 - val_mean_iou: 0.8251
# Epoch 7/10
# 38/38 [==============================] - ETA: 0s - loss: 0.0923 - mean_iou: 0.8068
# Epoch 7: val_loss improved from 0.08458 to 0.08420, saving model to model-dsbowl2018-1.h5
# 38/38 [==============================] - 51s 1s/step - loss: 0.0923 - mean_iou: 0.8068 - val_loss: 0.0842 - val_mean_iou: 0.8322
# Epoch 8/10
# 38/38 [==============================] - ETA: 0s - loss: 0.0909 - mean_iou: 0.8126
# Epoch 8: val_loss did not improve from 0.08420
# 38/38 [==============================] - 50s 1s/step - loss: 0.0909 - mean_iou: 0.8126 - val_loss: 0.0920 - val_mean_iou: 0.8140
# Epoch 9/10
# 38/38 [==============================] - ETA: 0s - loss: 0.0922 - mean_iou: 0.8083
# Epoch 9: val_loss did not improve from 0.08420
# 38/38 [==============================] - 51s 1s/step - loss: 0.0922 - mean_iou: 0.8083 - val_loss: 0.0853 - val_mean_iou: 0.8297
# Epoch 10/10
# 38/38 [==============================] - ETA: 0s - loss: 0.0907 - mean_iou: 0.8075
# Epoch 10: val_loss did not improve from 0.08420
# 38/38 [==============================] - 50s 1s/step - loss: 0.0907 - mean_iou: 0.8075 - val_loss: 0.0880 - val_mean_iou: 0.8373

# %%
model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)

preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 19/19 [==============================] - 8s 417ms/step
# 3/3 [==============================] - 1s 215ms/step
# 3/3 [==============================] - 1s 207ms/step

# %%
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(Y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()

# %%
ix = random.randint(0, len(preds_test_t))
imshow(X_train[int(X_train.shape[0]*0.9):][ix])
plt.show()
imshow(np.squeeze(Y_train[int(Y_train.shape[0]*0.9):][ix]))
plt.show()
imshow(np.squeeze(preds_test_t[ix]))
plt.show()

# %%
ix = random.randint(0, len(preds_test_t))
imshow(X_test[ix])
plt.show()
imshow(np.squeeze(preds_test_t[ix]))
plt.show()
